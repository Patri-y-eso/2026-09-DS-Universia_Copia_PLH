# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
var1 = 5
var2 = 2.
print("tipo de dato var1:",type(var1))
print("tipo de dato var2:",type(var2))
var_suma = var1 + var2
print("suma=",var_suma)
print("tipo de dato:",type(var_suma))
del var1, var2
# Out:
# tipo de dato var1: <class 'int'>
# tipo de dato var2: <class 'float'>
# suma= 7.0
# tipo de dato: <class 'float'>

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math

grados=4
radianes= grados * (math.pi/180)
print(radianes)
# Out:
# 0.06981317007977318

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base=6
altura=8
area=base*altura
print("El area es: ",area)
# Out:
# El area es:  48

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print(A==B)
print(A!=C)
print(A>C)
print(C<=A)
print(B!=C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
edad= 25
mes_de_nacimiento= 3
print("¿Son iguales las variables?: ", edad == mes_de_nacimiento)
# Out:
# ¿Son iguales las variables?:  False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
edad= 25
mes_de_nacim= 3
num_de_primos=4
print("¿Son iguales las variables?: ", edad == mes_de_nacim and edad==num_de_primos)
print("¿Son iguales al menos 2 variables variables?: ", edad == mes_de_nacim or edad==num_de_primos or mes_de_nacim==num_de_primos)
# Out:
# ¿Son iguales las variables?:  False
# ¿Son iguales al menos 2 variables variables?:  False

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
n1=4
n2=1
suma=n1+n2
print("Es mayor que 10:", suma>10)
print("Es menor que 10:", suma<10)
print("Es igual que 10:", suma==10)
# Out:
# Es mayor que 10: False
# Es menor que 10: True
# Es igual que 10: False

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista= [4, 6, 8, -1]
print("valor máximo: ", max(lista))
print("suma de elementos lista: ", sum(lista))
nume=63.451256965
print("redondeo a 3 digitos decimales", round(nume,3) )
print("valor absoluto de -74: ", abs(-74) )
# Out:
# valor máximo:  8
# suma de elementos lista:  17
# redondeo a 3 digitos decimales 63.451
# valor absoluto de -74:  74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
frase= "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
print("En mayusculas: ", frase.upper() )
print("En minusculas: ", frase.lower())
print("Primera letra de cada palabra en mayusculas: ", frase.title())
listaFrase= frase.split()
print("Lista de palabras por espacios: ", listaFrase )
print("Cambiendo las , por ; : ", frase.replace(",", ";"))
print("Eliminando las a minusculas: ", frase.replace("a",""))
# Out:
# En mayusculas:  EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.
# En minusculas:  en un lugar de la mancha, de cuyo nombre no quiero acordarme.
# Primera letra de cada palabra en mayusculas:  En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.
# Lista de palabras por espacios:  ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme.']
# Cambiendo las , por ; :  En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# Eliminando las a minusculas:  En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
ej11=[1,2,3]
print(ej11)
ej11.append(4)
print("Añado un elemento",ej11)
print("suma: ", sum(ej11))
ej11.remove(ej11[1])
print("Menos segundo elemento:", ej11)
ej11.insert(2,6)
print("Elemento añadido:", ej11)
lista2=[10,20,30]
final=ej11 + lista2
print("Final:",final)
# Out:
# [1, 2, 3]
# Añado un elemento [1, 2, 3, 4]
# suma:  10
# Menos segundo elemento: [1, 3, 4]
# Elemento añadido: [1, 3, 6, 4]
# Final: [1, 3, 6, 4, 10, 20, 30]
